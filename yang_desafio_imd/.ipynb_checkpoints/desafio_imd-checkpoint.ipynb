# %% [markdown]
# # Código referente ao Desafio Python IMD desenvolvido pelos integrantes Igor, Ricardo, Luiza e Yang para análise das Unidades Básicas de Saúde

# %%
import numpy as np
import pandas as pd
import folium
import copy

# %%
ubs = pd.read_csv('ubs.csv')
del ubs['cod_cnes']
del ubs['cod_munic']
del ubs['nom_estab']
del ubs['dsc_telefone']
del ubs['dsc_endereco']
clases = ['Desempenho mediano ou  um pouco abaixo da média','Desempenho acima da média','Desempenho muito acima da média']
brasil_epoch = 1000
#ubs.head(5)

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for i in range(0,brasil_epoch):
    if ubs['dsc_estrut_fisic_ambiencia'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_estrut_fisic_ambiencia'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_estrut_fisic_ambiencia'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_estrutura_brasil.html')

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for i in range(0,brasil_epoch):
    if ubs['dsc_adap_defic_fisic_idosos'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_adap_defic_fisic_idosos'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_adap_defic_fisic_idosos'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_acessibilidade_brasil.html')

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for i in range(0,brasil_epoch):
    if ubs['dsc_equipamentos'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_equipamentos'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_equipamentos'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_equipamentos_brasil.html')

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for i in range(0,brasil_epoch):
    if ubs['dsc_medicamentos'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_medicamentos'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_medicamentos'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_medicamentos_brasil.html')

# %%
ubs2 = copy.copy(ubs[ubs['dsc_cidade']=='Natal'])
ubs2.head()
# Out:
#       vlr_latitude  vlr_longitude    dsc_bairro dsc_cidade  \
# 2217     -5.762200     -35.271177  VALE DOURADO      Natal
# 2406     -5.773873     -35.196075           NaN      Natal
# 3529     -5.884402     -35.172536   PONTA NEGRA      Natal
# 3819     -5.760677     -35.261393       POTENGI      Natal
# 4025     -5.737159     -35.256972    LAGOA AZUL      Natal
#
#                            dsc_estrut_fisic_ambiencia  \
# 2217  Desempenho mediano ou  um pouco abaixo da média
# 2406                  Desempenho muito acima da média
# 3529  Desempenho mediano ou  um pouco abaixo da média
# 3819  Desempenho mediano ou  um pouco abaixo da média
# 4025  Desempenho mediano ou  um pouco abaixo da média
#
#                           dsc_adap_defic_fisic_idosos  \
# 2217  Desempenho mediano ou  um pouco abaixo da média
# 2406                  Desempenho muito acima da média
# 3529  Desempenho mediano ou  um pouco abaixo da média
# 3819                        Desempenho acima da média
# 4025  Desempenho mediano ou  um pouco abaixo da média
#
#                                      dsc_equipamentos  \
# 2217  Desempenho mediano ou  um pouco abaixo da média
# 2406  Desempenho mediano ou  um pouco abaixo da média
# 3529  Desempenho mediano ou  um pouco abaixo da média
# 3819  Desempenho mediano ou  um pouco abaixo da média
# 4025  Desempenho mediano ou  um pouco abaixo da média
#
#                                      dsc_medicamentos
# 2217  Desempenho mediano ou  um pouco abaixo da média
# 2406  Desempenho mediano ou  um pouco abaixo da média
# 3529  Desempenho mediano ou  um pouco abaixo da média
# 3819  Desempenho mediano ou  um pouco abaixo da média
# 4025  Desempenho mediano ou  um pouco abaixo da média

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for j in ubs2.iterrows():
    i = j[0]
    if ubs['dsc_estrut_fisic_ambiencia'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_estrut_fisic_ambiencia'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_estrut_fisic_ambiencia'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_estrutura_natal.html')

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for j in ubs2.iterrows():
    i = j[0]
    if ubs['dsc_adap_defic_fisic_idosos'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_adap_defic_fisic_idosos'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_adap_defic_fisic_idosos'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_acessibilidade_natal.html')

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for j in ubs2.iterrows():
    i = j[0]
    if ubs['dsc_equipamentos'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_equipamentos'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_equipamentos'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_equipamentos_natal.html')

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for j in ubs2.iterrows():
    i = j[0]
    if ubs['dsc_medicamentos'][i]==clases[0]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs['dsc_medicamentos'][i]==clases[1]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs['dsc_medicamentos'][i]==clases[2]:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_medicamentos_natal.html')

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
a = 3.3
b = 6.7
c = 10
ubs = pd.read_csv('ubs.csv')
ubs_natal = ubs[ubs['dsc_cidade']=='Natal']
ubs_natal['dsc_estrut_fisic_ambiencia'][ubs_natal['dsc_estrut_fisic_ambiencia'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_estrut_fisic_ambiencia'][ubs_natal['dsc_estrut_fisic_ambiencia'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_estrut_fisic_ambiencia'][ubs_natal['dsc_estrut_fisic_ambiencia'] == 'Desempenho muito acima da média'] = c
ubs_natal['dsc_adap_defic_fisic_idosos'][ubs_natal['dsc_adap_defic_fisic_idosos'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_adap_defic_fisic_idosos'][ubs_natal['dsc_adap_defic_fisic_idosos'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_adap_defic_fisic_idosos'][ubs_natal['dsc_adap_defic_fisic_idosos'] == 'Desempenho muito acima da média'] = c
ubs_natal['dsc_equipamentos'][ubs_natal['dsc_equipamentos'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_equipamentos'][ubs_natal['dsc_equipamentos'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_equipamentos'][ubs_natal['dsc_equipamentos'] == 'Desempenho muito acima da média'] = c
ubs_natal['dsc_medicamentos'][ubs_natal['dsc_medicamentos'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_medicamentos'][ubs_natal['dsc_medicamentos'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_medicamentos'][ubs_natal['dsc_medicamentos'] == 'Desempenho muito acima da média'] = c
# Out:
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/yang/.local/lib/python2.7/site-packages/pandas/core/generic.py:5233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /home/yang/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ubs_natal['media'] = (ubs_natal[:]['dsc_estrut_fisic_ambiencia'] + ubs_natal[:]['dsc_adap_defic_fisic_idosos'] + ubs_natal[:]['dsc_equipamentos'] + ubs_natal[:]['dsc_medicamentos'])/4
ubs_natal.head()
ubs_natal['media'].hist()
# Out:
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for j in ubs_natal.iterrows():
    i = j[0]
    if ubs_natal['media'][i]<=4:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs_natal['media'][i]>4 and ubs_natal['media'][i]<=8 :
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs_natal['media'][i]>8:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_notas_natal.html')

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
a = 3.3
b = 6.7
c = 10
ubs = pd.read_csv('ubs.csv')
ubs_natal = ubs
ubs_natal['dsc_estrut_fisic_ambiencia'][ubs_natal['dsc_estrut_fisic_ambiencia'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_estrut_fisic_ambiencia'][ubs_natal['dsc_estrut_fisic_ambiencia'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_estrut_fisic_ambiencia'][ubs_natal['dsc_estrut_fisic_ambiencia'] == 'Desempenho muito acima da média'] = c
ubs_natal['dsc_adap_defic_fisic_idosos'][ubs_natal['dsc_adap_defic_fisic_idosos'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_adap_defic_fisic_idosos'][ubs_natal['dsc_adap_defic_fisic_idosos'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_adap_defic_fisic_idosos'][ubs_natal['dsc_adap_defic_fisic_idosos'] == 'Desempenho muito acima da média'] = c
ubs_natal['dsc_equipamentos'][ubs_natal['dsc_equipamentos'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_equipamentos'][ubs_natal['dsc_equipamentos'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_equipamentos'][ubs_natal['dsc_equipamentos'] == 'Desempenho muito acima da média'] = c
ubs_natal['dsc_medicamentos'][ubs_natal['dsc_medicamentos'] == 'Desempenho mediano ou  um pouco abaixo da média'] = a
ubs_natal['dsc_medicamentos'][ubs_natal['dsc_medicamentos'] == 'Desempenho acima da média'] = b
ubs_natal['dsc_medicamentos'][ubs_natal['dsc_medicamentos'] == 'Desempenho muito acima da média'] = c
# Out:
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/yang/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ubs_natal['media'] = (ubs_natal[:]['dsc_estrut_fisic_ambiencia'] + ubs_natal[:]['dsc_adap_defic_fisic_idosos'] + ubs_natal[:]['dsc_equipamentos'] + ubs_natal[:]['dsc_medicamentos'])/4
ubs_natal['media'].hist()

# %%
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
for i in range(0,1000):
    if ubs_natal['media'][i]<=4:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='red',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
    
    if ubs_natal['media'][i]>4 and ubs_natal['media'][i]<=8 :
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='orange',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
        
    if ubs_natal['media'][i]>8:
        folium.Circle(
        location=[ubs['vlr_latitude'][i],ubs['vlr_longitude'][i]],
        popup="clan",
        radius=3,
        color='green',
        fill=True,
        fill_color='crimson'
        ).add_to(m)
m.save('mapa_notas_brasil.html')

# %%
ubs_brasil_mean = pd.Series([ubs['dsc_estrut_fisic_ambiencia'].mean(),  ubs['dsc_adap_defic_fisic_idosos'].mean(), ubs['dsc_medicamentos'].mean(), ubs['dsc_equipamentos'].mean()], index=['dsc_estrut_fisic_ambiencia', 'dsc_adap_defic_fisic_idosos', 'dsc_medicamentos', 'dsc_equipamentos'])
ubs_brasil_std = pd.Series([ubs['dsc_estrut_fisic_ambiencia'].std(),  ubs['dsc_adap_defic_fisic_idosos'].std(), ubs['dsc_medicamentos'].std(), ubs['dsc_equipamentos'].std()], index=['dsc_estrut_fisic_ambiencia', 'dsc_adap_defic_fisic_idosos', 'dsc_medicamentos', 'dsc_equipamentos'])

print 'Qualidade da estrutura física das UBS: ',ubs_brasil_mean[0],'+/-',ubs_brasil_std[0]
print 'Qualidade da acessibilidade na UBS: ',ubs_brasil_mean[1],'+/-',ubs_brasil_std[1]
print 'Disponibilidade de medicamentos na UBS: ',ubs_brasil_mean[2],'+/-',ubs_brasil_std[2]
print 'Qualidade dos equipamentos da UBS: ',ubs_brasil_mean[3],'+/-',ubs_brasil_std[3]
# Out:
# Qualidade da estrutura física das UBS:  5.31364022287 +/- 2.5971317253
# Qualidade da acessibilidade na UBS:  4.88886442027 +/- 2.33882493065
# Disponibilidade de medicamentos na UBS:  5.19389758557 +/- 2.30165348327
# Qualidade dos equipamentos da UBS:  4.11842398514 +/- 1.70332862608
